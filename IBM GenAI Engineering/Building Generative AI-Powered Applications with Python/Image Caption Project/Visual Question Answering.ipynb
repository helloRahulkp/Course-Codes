# %% [markdown]
# # BLIP can also answer questions about the content of an image

# %% [markdown]
# ## Import libraries

# %%
import requests
from PIL import Image
from transformers import BlipProcessor, BlipForConditionalGeneration

# %% [markdown]
# ## Laod BLIP processor and model

# %%
processor = Bli
